# %% [markdown]
# # Assignment 3
#
# ### Divija 102018056 CSBS3

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv('Americans_Time_spent_with_relationships_by_age.csv')

# %%
data_frame.head()
# Out:
#    Unnamed: 0         Entity Code  Year  \
# 0           0  United States  USA    15
# 1           1  United States  USA    16
# 2           2  United States  USA    17
# 3           3  United States  USA    18
# 4           4  United States  USA    19
#
#    Time spent alone, by age of respondent (United States)  \
# 0                                          193.30588
# 1                                          206.37056
# 2                                          224.17331
# 3                                          242.69839
# 4                                          267.79385
#
#    Time spent with friends, by age of respondent (United States)  \
# 0                                          109.41450
# 1                                          110.74180
# 2                                          120.41887
# 3                                          137.75107
# 4                                          129.85716
#
# ...

# %%
data_frame.drop(columns=data_frame.columns[0], axis=1, inplace=True)

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 9 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Entity                                                                                         67 non-null     object
#  1   Code                                                                                           67 non-null     object
#  2   Year                                                                                           67 non-null     int64
#  3   Time spent alone, by age of respondent (United States)                                         67 non-null     float64
#  4   Time spent with friends, by age of respondent (United States)                                  67 non-null     float64
# ...

# %%
data_frame.dtypes
# Out:
# Entity                                                                                            object
# Code                                                                                              object
# Year                                                                                               int64
# Time spent alone, by age of respondent (United States)                                           float64
# Time spent with friends, by age of respondent (United States)                                    float64
# Time spent with children, by age of respondent (United States)                                   float64
# Time spent with with parents, siblings and other family, by age of respondent (United States)    float64
# Time spent with partner, by age of respondent (United States)                                    float64
# Time spent with coworkers, by age of respondent (United States)                                  float64
# dtype: object

# %%
data_frame.head()
# Out:
#           Entity Code  Year  \
# 0  United States  USA    15
# 1  United States  USA    16
# 2  United States  USA    17
# 3  United States  USA    18
# 4  United States  USA    19
#
#    Time spent alone, by age of respondent (United States)  \
# 0                                          193.30588
# 1                                          206.37056
# 2                                          224.17331
# 3                                          242.69839
# 4                                          267.79385
#
#    Time spent with friends, by age of respondent (United States)  \
# 0                                          109.41450
# 1                                          110.74180
# 2                                          120.41887
# 3                                          137.75107
# 4                                          129.85716
#
#    Time spent with children, by age of respondent (United States)  \
# 0                                          23.463852
# ...

# %%
data_frame.mean()
# Out:
# Year                                                                                              48.059701
# Time spent alone, by age of respondent (United States)                                           348.618974
# Time spent with friends, by age of respondent (United States)                                     52.297102
# Time spent with children, by age of respondent (United States)                                   116.890738
# Time spent with with parents, siblings and other family, by age of respondent (United States)     81.602015
# Time spent with partner, by age of respondent (United States)                                    182.717405
# Time spent with coworkers, by age of respondent (United States)                                  125.286948
# dtype: float64

# %%
def mean_f(col):
    print('the mean is' , np.mean(col))
mean_f(data_frame['Time spent with friends, by age of respondent (United States)'])
# Out:
# the mean is 52.29710228358208

# %%
def median_f(col):
    print('the median is' , np.median(col))
median_f(data_frame['Time spent with coworkers, by age of respondent (United States)'])
# Out:
# the median is 162.92227

# %%
def find_min_max(col):
    print('the min of the col is'  , min(col))
    print ('the max of the col is' , max(col))
find_min_max(data_frame['Time spent with partner, by age of respondent (United States)'])
# Out:
# the min of the col is 0.0
# the max of the col is 276.13379

# %%
def standev(col):
    print('the standard deviation of the col is', np.std(col))
standev(data_frame['Time spent with coworkers, by age of respondent (United States)'])
# Out:
# the standard deviation of the col is 72.84445198072598

# %%
np.cov(data_frame['Time spent with friends, by age of respondent (United States)'],data_frame['Time spent with children, by age of respondent (United States)'])
# Out:
# array([[ 822.1229996 , -593.31969735],
#        [-593.31969735, 6067.39012042]])

# %%
data_frame.cov()
# Out:
#                                                            Year  \
# Year                                                 383.905473
# Time spent alone, by age of respondent (United ...  1631.494376
# Time spent with friends, by age of respondent (...  -400.755738
# Time spent with children, by age of respondent ...  -607.375461
# Time spent with with parents, siblings and othe...  -620.981379
# Time spent with partner, by age of respondent (...  1143.961773
# Time spent with coworkers, by age of respondent...  -898.577691
#
#                                                     Time spent alone, by age of respondent (United States)  \
# Year                                                                                      1631.494376
# Time spent alone, by age of respondent (United ...                                        7394.272566
# Time spent with friends, by age of respondent (...                                       -1434.307659
# ...

# %%
data_frame.corr()
# Out:
#                                                         Year  \
# Year                                                1.000000
# Time spent alone, by age of respondent (United ...  0.968335
# Time spent with friends, by age of respondent (... -0.713344
# Time spent with children, by age of respondent ... -0.397964
# Time spent with with parents, siblings and othe... -0.627429
# Time spent with partner, by age of respondent (...  0.809752
# Time spent with coworkers, by age of respondent... -0.624858
#
#                                                     Time spent alone, by age of respondent (United States)  \
# Year                                                                                         0.968335
# Time spent alone, by age of respondent (United ...                                           1.000000
# Time spent with friends, by age of respondent (...                                          -0.581736
# ...

# %%
np.corrcoef(data_frame['Time spent with children, by age of respondent (United States)'],data_frame['Time spent with friends, by age of respondent (United States)'])
# Out:
# array([[ 1.        , -0.26565586],
#        [-0.26565586,  1.        ]])

# %%
# import numpy as np

# # Get the number of attributes (columns)
# num_attributes = data_frame.shape[1]
# print(num_attributes)
# # Initialize a dictionary to store the covariance between each pair of attributes
# covariance = {}

# # Loop over each pair of attributes
# for i in range(num_attributes):
#     for j in range(i, num_attributes):
#         # Calculate the covariance between the two attributes
#         cov = np.cov(data_frame[:, i], data_frame[:, j])[0][1].values
        
#         # Get the name of the first attribute (column)
#         col1 = data_frame.columns[i]
        
#         # Get the name of the second attribute (column)
#         col2 = data_frame.columns[i+1]
        
#         # Store the covariance in the dictionary
#         covariance[(col1, col2)] = cov
        
# # Print the covariance dictionary
# print(covariance)

# %%
plt.hist(data_frame['Time spent alone, by age of respondent (United States)'])
plt.title('Time spent alone, by age of respondent (United States)')
plt.show()

# %%
data_frame['Time spent alone, by age of respondent (United States)'].plot.density(color='red')
plt.title('Density plot = Time spent alone, by age of respondent (United States)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,5))
sns.heatmap(data_frame.corr(), center=0, cmap='Blues')
ax.set_title('Multi-Collinearity of Time spent data')
# Out:
# Text(0.5, 1.0, 'Multi-Collinearity of Time spent data')

# %%
boxplot = data_frame.boxplot(figsize = (9,10), rot = 90, fontsize= '8', grid = False)
plt.title('Box Plot of the data')
plt.show()

# %%
plt.scatter(data_frame['Time spent alone, by age of respondent (United States)'],data_frame['Year'], s=100, alpha=0.6, c='red', edgecolor='black', linewidth=1)
plt.title('Time spent alone, by age of respondent (United States) V/S Year')
plt.show()

# %%
columns = ['Time spent alone, by age of respondent (United States)', 'Time spent with friends, by age of respondent (United States)','Time spent with children, by age of respondent (United States)', 'Time spent with with parents, siblings and other family, by age of respondent (United States)']
data =pd.read_csv('Americans_Time_spent_with_relationships_by_age.csv' ,  usecols=columns ) 
data.plot()
plt.show()
